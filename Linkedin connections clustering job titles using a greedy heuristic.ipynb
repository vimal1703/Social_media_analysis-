# %% [markdown]
# # Clustering job titles of Linkedin connections using a greedy heuristic

# %%
import os
import csv
import numpy as np

# Point this to your 'Connections.csv' file.
CSV_FILE = os.path.join('resources', 'ch04-linkedin', 'Connections.csv')

csvReader = csv.DictReader(open("Connections.csv"), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# %%
from nltk.util import bigrams

ceo_bigrams = list(bigrams("Chief Executive Officer".split(), pad_left=True, pad_right=True))
cto_bigrams = list(bigrams("Chief Technology Officer".split(), pad_left=True, pad_right=True))

print(ceo_bigrams)
print(cto_bigrams)

print(len(set(ceo_bigrams).intersection(set(cto_bigrams))))
# Out:
# [(None, 'Chief'), ('Chief', 'Executive'), ('Executive', 'Officer'), ('Officer', None)]
# [(None, 'Chief'), ('Chief', 'Technology'), ('Technology', 'Officer'), ('Officer', None)]
# 2

# %% [markdown]
# ### Jaccard distance calculation

# %%
from nltk.metrics.distance import jaccard_distance # pip install nltk

job_title_1 = 'Chief Executive Officer'.split()
job_title_2 = 'Chief Technology Officer'.split()

print(job_title_1)
print(job_title_2)

print()
print('Intersection:')
intersection = set(job_title_1).intersection(set(job_title_2))
print(intersection)

print()
print('Union:')
union = set(job_title_1).union(set(job_title_2))
print(union)

print()
print('Similarity:', len(intersection) / len(union))
print('Distance:', jaccard_distance(set(job_title_1), set(job_title_2)))
# Out:
# ['Chief', 'Executive', 'Officer']
# ['Chief', 'Technology', 'Officer']
#
# Intersection:
# {'Chief', 'Officer'}
#
# Union:
# {'Executive', 'Chief', 'Officer', 'Technology'}
#
# Similarity: 0.5
# Distance: 0.5

# %%
job_title_1 = 'Vice President, Sales'.split()
job_title_2 = 'Vice President, Customer Relations'.split()

print(job_title_1)
print(job_title_2)

print()
print('Intersection:')
intersection = set(job_title_1).intersection(set(job_title_2))
print(intersection)

print()
print('Union:')
union = set(job_title_1).union(set(job_title_2))
print(union)

print()
print('Similarity:', len(intersection) / len(union))
print('Distance:', jaccard_distance(set(job_title_1), set(job_title_2)))
# Out:
# ['Vice', 'President,', 'Sales']
# ['Vice', 'President,', 'Customer', 'Relations']
#
# Intersection:
# {'President,', 'Vice'}
#
# Union:
# {'President,', 'Customer', 'Sales', 'Relations', 'Vice'}
#
# Similarity: 0.4
# Distance: 0.6

# %%
contacts
# Out:
# [OrderedDict([('First Name', 'Rahul'),
#               ('Last Name', 'Venkat S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '08-Aug-22')]),
#  OrderedDict([('First Name', 'MUTHULASKMI'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '07-Aug-22')]),
#  OrderedDict([('First Name', 'Jaganbharathi'),
#               ('Last Name', 'K R'),
#               ('Email Address', ''),
#               ('Company', 'Home tution 12'),
#               ('Position', 'Teacher'),
#               ('Connected On', '02-Aug-22')]),
#  OrderedDict([('First Name', 'Jefferson'),
#               ('Last Name', 'Roosevelt'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '29-Jul-22')]),
#  OrderedDict([('First Name', 'Hannah'),
#               ('Last Name', 'Weniez'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '27-Jul-22')]),
#  OrderedDict([('First Name', 'Dhivyadharshni'),
#               ('Last Name', 'Natarajan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '11-Jun-22')]),
#  OrderedDict([('First Name', 'Eliahim'),
#               ('Last Name', 'Jeevaraj'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Assistant Professor'),
#               ('Connected On', '21-May-22')]),
#  OrderedDict([('First Name', 'Joshua Sundar Raja'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', 'Mendeley'),
#               ('Position', 'Advisor'),
#               ('Connected On', '20-May-22')]),
#  OrderedDict([('First Name', 'Tanya'),
#               ('Last Name', 'Asthana'),
#               ('Email Address', ''),
#               ('Company', 'TechieNest'),
#               ('Position', 'Intern'),
#               ('Connected On', '18-May-22')]),
#  OrderedDict([('First Name', 'Maneesh'),
#               ('Last Name', 'Praveen'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '08-May-22')]),
#  OrderedDict([('First Name', 'Surbhi'),
#               ('Last Name', 'Samdani'),
#               ('Email Address', ''),
#               ('Company', 'TechieNest'),
#               ('Position', 'Management Intern'),
#               ('Connected On', '30-Apr-22')]),
#  OrderedDict([('First Name', 'Rithika '),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '27-Apr-22')]),
#  OrderedDict([('First Name', 'HARI VIGNESH '),
#               ('Last Name', 'M'),
#               ('Email Address', ''),
#               ('Company', 'Unschool '),
#               ('Position', 'Operations Trainee'),
#               ('Connected On', '23-Apr-22')]),
#  OrderedDict([('First Name', 'Divya'),
#               ('Last Name', 'Duraisamy'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '22-Apr-22')]),
#  OrderedDict([('First Name', 'Mohammed'),
#               ('Last Name', 'Aamir'),
#               ('Email Address', ''),
#               ('Company', 'Wood'),
#               ('Position', 'Piping Designer at WOOD'),
#               ('Connected On', '22-Apr-22')]),
#  OrderedDict([('First Name', 'Vaishnavi'),
#               ('Last Name', 'Murugesan'),
#               ('Email Address', ''),
#               ('Company', 'Freelance'),
#               ('Position', 'Content Writer'),
#               ('Connected On', '07-Apr-22')]),
#  OrderedDict([('First Name', 'Ravinathan'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'The Sparks Foundation'),
#               ('Position', 'Data Science and Business Analytics Intern'),
#               ('Connected On', '06-Apr-22')]),
#  OrderedDict([('First Name', 'JERRY'),
#               ('Last Name', 'HEART K'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '29-Mar-22')]),
#  OrderedDict([('First Name', 'Bharathwin'),
#               ('Last Name', 'MA'),
#               ('Email Address', ''),
#               ('Company', 'KPMG India'),
#               ('Position', 'Data Analytics consulting Virtual Internship'),
#               ('Connected On', '24-Mar-22')]),
#  OrderedDict([('First Name', 'Rahini'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '24-Mar-22')]),
#  OrderedDict([('First Name', 'Jemima'),
#               ('Last Name', 'Gracia'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Research Scholar'),
#               ('Connected On', '24-Mar-22')]),
#  OrderedDict([('First Name', 'Arjun'),
#               ('Last Name', 'V S'),
#               ('Email Address', ''),
#               ('Company', 'Mila - Quebec Artificial Intelligence Institute'),
#               ('Position', 'Student Researcher'),
#               ('Connected On', '23-Mar-22')]),
#  OrderedDict([('First Name', 'ranjani'),
#               ('Last Name', 'balasubramanian'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '23-Mar-22')]),
#  OrderedDict([('First Name', 'DHANAPRIYA'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '23-Mar-22')]),
#  OrderedDict([('First Name', 'Deepika'),
#               ('Last Name', 'Murugan'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '23-Mar-22')]),
#  OrderedDict([('First Name', 'E'),
#               ('Last Name', 'Sundar'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '09-Feb-22')]),
#  OrderedDict([('First Name', 'viki'),
#               ('Last Name', 'viki'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Karthik'),
#               ('Last Name', 'Devaraj'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Kirubha'),
#               ('Last Name', 'Karan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'MUHIL'),
#               ('Last Name', 'ARASAN'),
#               ('Email Address', ''),
#               ('Company', 'Merkle'),
#               ('Position', 'Associate Analyst'),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Harsha'),
#               ('Last Name', 'vardhan'),
#               ('Email Address', ''),
#               ('Company', 'Wipro'),
#               ('Position', 'Scholar Trainee'),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Ebenezer'),
#               ('Last Name', 'Veda Sundaram'),
#               ('Email Address', ''),
#               ('Company', 'Youth for Math BHC'),
#               ('Position', 'Co Author'),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Sherine'),
#               ('Last Name', 'Raymon Johns'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Sam'),
#               ('Last Name', 'Daniel Raj'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'ISAAC'),
#               ('Last Name', 'NARESH'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '31-Dec-21')]),
#  OrderedDict([('First Name', 'Nivetha'),
#               ('Last Name', 'Murugan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '31-Dec-21')]),
#  OrderedDict([('First Name', 'Dr. Suresh'),
#               ('Last Name', 'Kannaiyan, Ph.D.,'),
#               ('Email Address', ''),
#               ('Company', 'MENMOZHI TECHNOLOGIES'),
#               ('Position', 'Founder | Proprietor'),
#               ('Connected On', '03-Dec-21')]),
#  OrderedDict([('First Name', 'Priyadarshini'),
#               ('Last Name', 'Ravichandran'),
#               ('Email Address', ''),
#               ('Company', 'TalkSmart'),
#               ('Position', 'Communication Evangelist '),
#               ('Connected On', '01-Dec-21')]),
#  OrderedDict([('First Name', 'Arunachalam'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '01-Dec-21')]),
#  OrderedDict([('First Name', 'VIMAL'),
#               ('Last Name', 'S E'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '29-Nov-21')]),
#  OrderedDict([('First Name', 'Hariharasudhan'),
#               ('Last Name', 'D'),
#               ('Email Address', ''),
#               ('Company', 'MENMOZHI TECHNOLOGIES'),
#               ('Position', 'Intern'),
#               ('Connected On', '29-Nov-21')]),
#  OrderedDict([('First Name', 'Rithik'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'Tech Mahindra'),
#               ('Position', 'Business Associate'),
#               ('Connected On', '23-Nov-21')]),
#  OrderedDict([('First Name', 'Sharon'),
#               ('Last Name', 'Nissi'),
#               ('Email Address', ''),
#               ('Company',
#                'Shanmugha Arts, Science, Technology & Research Academy (SASTRA), Thanjavur'),
#               ('Position', 'Research Student'),
#               ('Connected On', '23-Nov-21')]),
#  OrderedDict([('First Name', 'ARAVINTHAN'),
#               ('Last Name', 'K'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '14-Nov-21')]),
#  OrderedDict([('First Name', 'Jayasurya'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', 'Actify Data Labs'),
#               ('Position', 'Data Analyst'),
#               ('Connected On', '08-Nov-21')]),
#  OrderedDict([('First Name', 'Kelvin'),
#               ('Last Name', 'Christober'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '08-Nov-21')]),
#  OrderedDict([('First Name', 'Vincy'),
#               ('Last Name', 'Shally'),
#               ('Email Address', 'vincyshallyeden@gmail.com'),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Assistant Professor'),
#               ('Connected On', '08-Nov-21')]),
#  OrderedDict([('First Name', 'Joel'),
#               ('Last Name', 'Andrews Jeyakumar'),
#               ('Email Address', ''),
#               ('Company', 'CGI'),
#               ('Position', 'Associate Software Engineer'),
#               ('Connected On', '08-Nov-21')]),
#  OrderedDict([('First Name', 'Swathi'),
#               ('Last Name', 'Santhanam'),
#               ('Email Address', ''),
#               ('Company', 'Chegg Inc.'),
#               ('Position', 'SME'),
#               ('Connected On', '02-Nov-21')]),
#  OrderedDict([('First Name', 'Yokeshwaran '),
#               ('Last Name', 'G'),
#               ('Email Address', ''),
#               ('Company', 'Learn and Build'),
#               ('Position', 'Summer Intern'),
#               ('Connected On', '31-Oct-21')]),
#  OrderedDict([('First Name', 'Naveen'),
#               ('Last Name', 'Madhavan'),
#               ('Email Address', ''),
#               ('Company', 'Capgemini'),
#               ('Position', 'Human Resources Analyst'),
#               ('Connected On', '30-Oct-21')]),
#  OrderedDict([('First Name', 'Rajesh'),
#               ('Last Name', 'Kannan M'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '30-Oct-21')]),
#  OrderedDict([('First Name', 'Berchmans'),
#               ('Last Name', 'Kevin S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '30-Oct-21')]),
#  OrderedDict([('First Name', 'SAMIDURAI'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '27-Oct-21')]),
#  OrderedDict([('First Name', 'ABISHEK'),
#               ('Last Name', 'N'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '25-Oct-21')]),
#  OrderedDict([('First Name', 'Jemimah'),
#               ('Last Name', 'Kandaraj'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Guest Lecturer'),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Sujith'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Jerry'),
#               ('Last Name', 'Anto'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Bharat'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Saravanan'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Ajithra'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Kausalya'),
#               ('Last Name', 'Sivakumar'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '03-Oct-21')]),
#  OrderedDict([('First Name', 'Eugene'),
#               ('Last Name', 'Kingsley'),
#               ('Email Address', ''),
#               ('Company', 'Kissflow'),
#               ('Position', 'Technical Solution Specialist'),
#               ('Connected On', '02-Oct-21')]),
#  OrderedDict([('First Name', 'Rexson'),
#               ('Last Name', 'Epiron'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '02-Oct-21')]),
#  OrderedDict([('First Name', 'Maria'),
#               ('Last Name', 'Karthika'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '01-Oct-21')]),
#  OrderedDict([('First Name', 'Jo-Anna'),
#               ('Last Name', 'Elizabeth J'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '01-Oct-21')]),
#  OrderedDict([('First Name', 'Rajkumar'),
#               ('Last Name', 'Kannan'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Dean - Deanery International Relations'),
#               ('Connected On', '30-Sep-21')]),
#  OrderedDict([('First Name', 'Vasavi'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '30-Sep-21')]),
#  OrderedDict([('First Name', 'Janani'),
#               ('Last Name', 'Selvaraj PhD'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Guest Lecturer'),
#               ('Connected On', '29-Sep-21')]),
#  OrderedDict([('First Name', 'ARUN'),
#               ('Last Name', 'KUMAR M'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '29-Sep-21')]),
#  OrderedDict([('First Name', 'Nambirajan'),
#               ('Last Name', 'R S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '29-Sep-21')]),
#  OrderedDict([('First Name', 'Ashika'),
#               ('Last Name', 'Devi'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ''),
#               ('Connected On', '29-Sep-21')]),
#  OrderedDict([('First Name', 'Surya'),
#               ('Last Name', 'Prakash'),
#               ('Email Address', ''),
#               ('Company', 'central workshop, southern railway '),
#               ('Position', 'Student'),
#               ('Connected On', '12-May-21')])]

# %%
import json
# Tweak this distance threshold and try different distance calculations 
# during experimentation
DISTANCE_THRESHOLD = 0.6
DISTANCE = jaccard_distance



def cluster_contacts_by_title():

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', ' and ', ' & ', '|', ',']

    # Normalize and/or replace known abbreviations
    # and build up a list of common titles.

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Position'] == '':
            contacts[i]['Position'] = ['']
            continue
        titles = [contacts[i]['Position']]
        
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or title2 in clusters and title1 \
                in clusters[title2]:
                continue
            try:
                distance = DISTANCE(set(title1.split()), set(title2.split()))
            except:
                print(title1.split())
                print(title2.split())
                continue

            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)

    # Flatten out clusters
    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]

    # Round up contacts who are in these clusters and group them together
    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Position']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('{0} {1}.'.format(
                        contact['FirstName'], contact['LastName'][0]))

    return clustered_contacts


clustered_contacts = cluster_contacts_by_title()

for titles in clustered_contacts:
    common_titles_heading = 'Common Titles: ' + ', '.join(titles)

    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    if len(descriptive_terms) == 0: descriptive_terms = ['***No words in common***']
    descriptive_terms_heading = 'Descriptive Terms: ' \
        + ', '.join(descriptive_terms)
    print(common_titles_heading)
    print('\n'+descriptive_terms_heading)
    print('-' * 70)
    print('\n'.join(clustered_contacts[titles]))
    print()
# Out:
# Common Titles: Intern, Management Intern, Summer Intern
#
# Descriptive Terms: Intern
# ----------------------------------------------------------------------
#
#
# Common Titles: Student, Research Student, Student Researcher
#
# Descriptive Terms: Student
# ----------------------------------------------------------------------

# %% [markdown]
# ### How to export data to power a dendogram and node-link tree visualization

# %%
import cluster

# %%
contacts
# Out:
# [OrderedDict([('First Name', 'Rahul'),
#               ('Last Name', 'Venkat S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '08-Aug-22')]),
#  OrderedDict([('First Name', 'MUTHULASKMI'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '07-Aug-22')]),
#  OrderedDict([('First Name', 'Jaganbharathi'),
#               ('Last Name', 'K R'),
#               ('Email Address', ''),
#               ('Company', 'Home tution 12'),
#               ('Position', 'Teacher'),
#               ('Connected On', '02-Aug-22')]),
#  OrderedDict([('First Name', 'Jefferson'),
#               ('Last Name', 'Roosevelt'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '29-Jul-22')]),
#  OrderedDict([('First Name', 'Hannah'),
#               ('Last Name', 'Weniez'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '27-Jul-22')]),
#  OrderedDict([('First Name', 'Dhivyadharshni'),
#               ('Last Name', 'Natarajan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '11-Jun-22')]),
#  OrderedDict([('First Name', 'Eliahim'),
#               ('Last Name', 'Jeevaraj'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Assistant Professor'),
#               ('Connected On', '21-May-22')]),
#  OrderedDict([('First Name', 'Joshua Sundar Raja'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', 'Mendeley'),
#               ('Position', 'Advisor'),
#               ('Connected On', '20-May-22')]),
#  OrderedDict([('First Name', 'Tanya'),
#               ('Last Name', 'Asthana'),
#               ('Email Address', ''),
#               ('Company', 'TechieNest'),
#               ('Position', 'Intern'),
#               ('Connected On', '18-May-22')]),
#  OrderedDict([('First Name', 'Maneesh'),
#               ('Last Name', 'Praveen'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '08-May-22')]),
#  OrderedDict([('First Name', 'Surbhi'),
#               ('Last Name', 'Samdani'),
#               ('Email Address', ''),
#               ('Company', 'TechieNest'),
#               ('Position', 'Management Intern'),
#               ('Connected On', '30-Apr-22')]),
#  OrderedDict([('First Name', 'Rithika '),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '27-Apr-22')]),
#  OrderedDict([('First Name', 'HARI VIGNESH '),
#               ('Last Name', 'M'),
#               ('Email Address', ''),
#               ('Company', 'Unschool '),
#               ('Position', 'Operations Trainee'),
#               ('Connected On', '23-Apr-22')]),
#  OrderedDict([('First Name', 'Divya'),
#               ('Last Name', 'Duraisamy'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '22-Apr-22')]),
#  OrderedDict([('First Name', 'Mohammed'),
#               ('Last Name', 'Aamir'),
#               ('Email Address', ''),
#               ('Company', 'Wood'),
#               ('Position', 'Piping Designer at WOOD'),
#               ('Connected On', '22-Apr-22')]),
#  OrderedDict([('First Name', 'Vaishnavi'),
#               ('Last Name', 'Murugesan'),
#               ('Email Address', ''),
#               ('Company', 'Freelance'),
#               ('Position', 'Content Writer'),
#               ('Connected On', '07-Apr-22')]),
#  OrderedDict([('First Name', 'Ravinathan'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'The Sparks Foundation'),
#               ('Position', 'Data Science and Business Analytics Intern'),
#               ('Connected On', '06-Apr-22')]),
#  OrderedDict([('First Name', 'JERRY'),
#               ('Last Name', 'HEART K'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '29-Mar-22')]),
#  OrderedDict([('First Name', 'Bharathwin'),
#               ('Last Name', 'MA'),
#               ('Email Address', ''),
#               ('Company', 'KPMG India'),
#               ('Position', 'Data Analytics consulting Virtual Internship'),
#               ('Connected On', '24-Mar-22')]),
#  OrderedDict([('First Name', 'Rahini'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '24-Mar-22')]),
#  OrderedDict([('First Name', 'Jemima'),
#               ('Last Name', 'Gracia'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Research Scholar'),
#               ('Connected On', '24-Mar-22')]),
#  OrderedDict([('First Name', 'Arjun'),
#               ('Last Name', 'V S'),
#               ('Email Address', ''),
#               ('Company', 'Mila - Quebec Artificial Intelligence Institute'),
#               ('Position', 'Student Researcher'),
#               ('Connected On', '23-Mar-22')]),
#  OrderedDict([('First Name', 'ranjani'),
#               ('Last Name', 'balasubramanian'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '23-Mar-22')]),
#  OrderedDict([('First Name', 'DHANAPRIYA'),
#               ('Last Name', 'A'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '23-Mar-22')]),
#  OrderedDict([('First Name', 'Deepika'),
#               ('Last Name', 'Murugan'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Data Scientist'),
#               ('Connected On', '23-Mar-22')]),
#  OrderedDict([('First Name', 'E'),
#               ('Last Name', 'Sundar'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '09-Feb-22')]),
#  OrderedDict([('First Name', 'viki'),
#               ('Last Name', 'viki'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Karthik'),
#               ('Last Name', 'Devaraj'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Kirubha'),
#               ('Last Name', 'Karan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'MUHIL'),
#               ('Last Name', 'ARASAN'),
#               ('Email Address', ''),
#               ('Company', 'Merkle'),
#               ('Position', 'Associate Analyst'),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Harsha'),
#               ('Last Name', 'vardhan'),
#               ('Email Address', ''),
#               ('Company', 'Wipro'),
#               ('Position', 'Scholar Trainee'),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Ebenezer'),
#               ('Last Name', 'Veda Sundaram'),
#               ('Email Address', ''),
#               ('Company', 'Youth for Math BHC'),
#               ('Position', 'Co Author'),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Sherine'),
#               ('Last Name', 'Raymon Johns'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'Sam'),
#               ('Last Name', 'Daniel Raj'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '26-Jan-22')]),
#  OrderedDict([('First Name', 'ISAAC'),
#               ('Last Name', 'NARESH'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '31-Dec-21')]),
#  OrderedDict([('First Name', 'Nivetha'),
#               ('Last Name', 'Murugan'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '31-Dec-21')]),
#  OrderedDict([('First Name', 'Dr. Suresh'),
#               ('Last Name', 'Kannaiyan, Ph.D.,'),
#               ('Email Address', ''),
#               ('Company', 'MENMOZHI TECHNOLOGIES'),
#               ('Position', 'Founder | Proprietor'),
#               ('Connected On', '03-Dec-21')]),
#  OrderedDict([('First Name', 'Priyadarshini'),
#               ('Last Name', 'Ravichandran'),
#               ('Email Address', ''),
#               ('Company', 'TalkSmart'),
#               ('Position', 'Communication Evangelist '),
#               ('Connected On', '01-Dec-21')]),
#  OrderedDict([('First Name', 'Arunachalam'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '01-Dec-21')]),
#  OrderedDict([('First Name', 'VIMAL'),
#               ('Last Name', 'S E'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '29-Nov-21')]),
#  OrderedDict([('First Name', 'Hariharasudhan'),
#               ('Last Name', 'D'),
#               ('Email Address', ''),
#               ('Company', 'MENMOZHI TECHNOLOGIES'),
#               ('Position', 'Intern'),
#               ('Connected On', '29-Nov-21')]),
#  OrderedDict([('First Name', 'Rithik'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', 'Tech Mahindra'),
#               ('Position', 'Business Associate'),
#               ('Connected On', '23-Nov-21')]),
#  OrderedDict([('First Name', 'Sharon'),
#               ('Last Name', 'Nissi'),
#               ('Email Address', ''),
#               ('Company',
#                'Shanmugha Arts, Science, Technology & Research Academy (SASTRA), Thanjavur'),
#               ('Position', 'Research Student'),
#               ('Connected On', '23-Nov-21')]),
#  OrderedDict([('First Name', 'ARAVINTHAN'),
#               ('Last Name', 'K'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '14-Nov-21')]),
#  OrderedDict([('First Name', 'Jayasurya'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', 'Actify Data Labs'),
#               ('Position', 'Data Analyst'),
#               ('Connected On', '08-Nov-21')]),
#  OrderedDict([('First Name', 'Kelvin'),
#               ('Last Name', 'Christober'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '08-Nov-21')]),
#  OrderedDict([('First Name', 'Vincy'),
#               ('Last Name', 'Shally'),
#               ('Email Address', 'vincyshallyeden@gmail.com'),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Assistant Professor'),
#               ('Connected On', '08-Nov-21')]),
#  OrderedDict([('First Name', 'Joel'),
#               ('Last Name', 'Andrews Jeyakumar'),
#               ('Email Address', ''),
#               ('Company', 'CGI'),
#               ('Position', 'Associate Software Engineer'),
#               ('Connected On', '08-Nov-21')]),
#  OrderedDict([('First Name', 'Swathi'),
#               ('Last Name', 'Santhanam'),
#               ('Email Address', ''),
#               ('Company', 'Chegg Inc.'),
#               ('Position', 'SME'),
#               ('Connected On', '02-Nov-21')]),
#  OrderedDict([('First Name', 'Yokeshwaran '),
#               ('Last Name', 'G'),
#               ('Email Address', ''),
#               ('Company', 'Learn and Build'),
#               ('Position', 'Summer Intern'),
#               ('Connected On', '31-Oct-21')]),
#  OrderedDict([('First Name', 'Naveen'),
#               ('Last Name', 'Madhavan'),
#               ('Email Address', ''),
#               ('Company', 'Capgemini'),
#               ('Position', 'Human Resources Analyst'),
#               ('Connected On', '30-Oct-21')]),
#  OrderedDict([('First Name', 'Rajesh'),
#               ('Last Name', 'Kannan M'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '30-Oct-21')]),
#  OrderedDict([('First Name', 'Berchmans'),
#               ('Last Name', 'Kevin S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '30-Oct-21')]),
#  OrderedDict([('First Name', 'SAMIDURAI'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '27-Oct-21')]),
#  OrderedDict([('First Name', 'ABISHEK'),
#               ('Last Name', 'N'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '25-Oct-21')]),
#  OrderedDict([('First Name', 'Jemimah'),
#               ('Last Name', 'Kandaraj'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Guest Lecturer'),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Sujith'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Jerry'),
#               ('Last Name', 'Anto'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Bharat'),
#               ('Last Name', 'V'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Saravanan'),
#               ('Last Name', 'S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Ajithra'),
#               ('Last Name', 'P'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '23-Oct-21')]),
#  OrderedDict([('First Name', 'Kausalya'),
#               ('Last Name', 'Sivakumar'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '03-Oct-21')]),
#  OrderedDict([('First Name', 'Eugene'),
#               ('Last Name', 'Kingsley'),
#               ('Email Address', ''),
#               ('Company', 'Kissflow'),
#               ('Position', 'Technical Solution Specialist'),
#               ('Connected On', '02-Oct-21')]),
#  OrderedDict([('First Name', 'Rexson'),
#               ('Last Name', 'Epiron'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '02-Oct-21')]),
#  OrderedDict([('First Name', 'Maria'),
#               ('Last Name', 'Karthika'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '01-Oct-21')]),
#  OrderedDict([('First Name', 'Jo-Anna'),
#               ('Last Name', 'Elizabeth J'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '01-Oct-21')]),
#  OrderedDict([('First Name', 'Rajkumar'),
#               ('Last Name', 'Kannan'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Dean - Deanery International Relations'),
#               ('Connected On', '30-Sep-21')]),
#  OrderedDict([('First Name', 'Vasavi'),
#               ('Last Name', 'R'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '30-Sep-21')]),
#  OrderedDict([('First Name', 'Janani'),
#               ('Last Name', 'Selvaraj PhD'),
#               ('Email Address', ''),
#               ('Company', 'Bishop Heber College, Tiruchirappalli - 620 017.'),
#               ('Position', 'Guest Lecturer'),
#               ('Connected On', '29-Sep-21')]),
#  OrderedDict([('First Name', 'ARUN'),
#               ('Last Name', 'KUMAR M'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '29-Sep-21')]),
#  OrderedDict([('First Name', 'Nambirajan'),
#               ('Last Name', 'R S'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '29-Sep-21')]),
#  OrderedDict([('First Name', 'Ashika'),
#               ('Last Name', 'Devi'),
#               ('Email Address', ''),
#               ('Company', ''),
#               ('Position', ['']),
#               ('Connected On', '29-Sep-21')]),
#  OrderedDict([('First Name', 'Surya'),
#               ('Last Name', 'Prakash'),
#               ('Email Address', ''),
#               ('Company', 'central workshop, southern railway '),
#               ('Position', 'Student'),
#               ('Connected On', '12-May-21')])]

# %%
import nltk
nltk.download('stopwords')
from nltk.metrics.distance import jaccard_distance
from nltk.corpus import stopwords 
from cluster import HierarchicalClustering 
import os
from collections import Counter
CSV_FILE = os.path.join('Connections.csv')

# Tweak this distance threshold and try different distance calculations 
# during experimentation
DISTANCE_THRESHOLD = 0.5
DISTANCE = jaccard_distance

# Adjust sample size as needed to reduce the runtime of the
# nested loop that invokes the DISTANCE function
SAMPLE_SIZE = 500

def cluster_contacts_by_title(csv_file):

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]
    contacts = contacts[:SAMPLE_SIZE]
    
    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', ' and ', '|', ',', ' & ']

    # Normalize and/or replace known abbreviations
    # and build up a list of common titles.

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Position'] == '':
            contacts[i]['Position'] = ['']
            continue
        titles = [contacts[i]['Position']]
        for separator in separators:
            for title in titles:
                if title.find(separator) >= 0:
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator) if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
            
        contacts[i]['Position'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))
    
    # Define a scoring function
    def score(title1, title2): 
        return DISTANCE(set(title1.split()), set(title2.split()))

    # Feed the class your data and the scoring function
    hc = HierarchicalClustering(all_titles, score)

    # Cluster the data according to a distance threshold
    clusters = hc.getlevel(DISTANCE_THRESHOLD)

    # Remove singleton clusters
    clusters = [c for c in clusters if len(c) > 1]

    # Round up contacts who are in these clusters and group them together
    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Position']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('{0} {1}.'.format(
                        contact['First Name'], contact['Last Name'][0]))

    return clustered_contacts, clusters

def get_descriptive_terms(titles):
    flatten = lambda l: [item for sublist in l for item in sublist]
    title_words = flatten([title.split() for title in titles])
    filtered_words = [word for word in title_words \
                      if word not in stopwords.words('english')]
    counter = Counter(filtered_words)
    descriptive_terms = counter.most_common(2)
    # Get the most common title words from a cluster, ignoring singletons
    descriptive_terms = [t[0] for t in descriptive_terms if t[1] > 1]
    return descriptive_terms


def display_output(clustered_contacts, clusters):    
    for title_cluster in clusters:
        descriptive_terms = get_descriptive_terms(title_cluster)
        common_titles_heading = 'Common Titles: ' + ', '.join((t for t in title_cluster))
        descriptive_terms_heading =  'Descriptive Terms: ' + ', '.join((t for t in descriptive_terms))
        
        print(common_titles_heading)
        print(descriptive_terms_heading)
        print('-' * 70)
        #print(title_cluster)
        #print(clustered_contacts)
        print('\n'.join(clustered_contacts[tuple(title_cluster)]))
        print()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\online.CSCENTER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
clustered_contacts
# Out:
# {('Student Researcher', 'Research Student', 'Student'): ['Arjun V.',
#   'Sharon N.',
#   'Surya P.'],
#  ('Summer Intern', 'Intern', 'Management Intern'): ['Tanya A.',
#   'Surbhi S.',
#   'Hariharasudhan D.',
#   'Yokeshwaran  G.']}

# %%
def write_d3_json_output(clustered_contacts):
    
    json_output = {'name' : 'My LinkedIn', 'children' : []}

    for titles in clustered_contacts:

        descriptive_terms = get_descriptive_terms(titles)

        json_output['children'].append({'name' : ', '.join(descriptive_terms)[:30], 'children' : [ {'name' : c} for c in clustered_contacts[titles] ] } )
        with open("sample.json", "w") as out_file:
            json.dump(json_output,out_file,indent=1)
            out_file.close()
    
clustered_contacts, clusters = cluster_contacts_by_title(CSV_FILE)
display_output(clustered_contacts, clusters)
write_d3_json_output(clustered_contacts)
# Out:
# Common Titles: Student Researcher, Research Student, Student
# Descriptive Terms: Student
# ----------------------------------------------------------------------
# Arjun V.
# Sharon N.
# Surya P.
#
# Common Titles: Summer Intern, Intern, Management Intern
# Descriptive Terms: Intern
# ----------------------------------------------------------------------
# Tanya A.
# Surbhi S.
# Hariharasudhan D.
# Yokeshwaran  G.
